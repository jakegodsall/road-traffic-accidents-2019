# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# instantiating StandardScaler object
scaler = StandardScaler()
encoder = LabelEncoder()

# separating out the features
features = iris.columns[:-1]
target = iris.columns[-1]

# creating the datasets
X = iris.loc[:, features].values
y = iris.loc[:, target].values

# scaling values
X = scaler.fit_transform(X)

# encoding labels
y = encoder.fit_transform(y)

# %%
from sklearn.decomposition import PCA

components = 4

pca = PCA(n_components=components)

principal_components = pca.fit_transform(X)

col_names = []
for i in range(components):
    col_names.append(f"component {i+1}")

principal_df = pd.DataFrame(data=principal_components,
                            columns=col_names)

principal_df = pd.concat([principal_df, iris[target]], axis=1)

principal_df
# Out:
#      component 1  component 2  component 3  component 4    species
# 0      -2.264703     0.480027    -0.127706    -0.024168     setosa
# 1      -2.080961    -0.674134    -0.234609    -0.103007     setosa
# 2      -2.364229    -0.341908     0.044201    -0.028377     setosa
# 3      -2.299384    -0.597395     0.091290     0.065956     setosa
# 4      -2.389842     0.646835     0.015738     0.035923     setosa
# ..           ...          ...          ...          ...        ...
# 145     1.870503     0.386966     0.256274    -0.389257  virginica
# 146     1.564580    -0.896687    -0.026371    -0.220192  virginica
# 147     1.521170     0.269069     0.180178    -0.119171  virginica
# 148     1.372788     1.011254     0.933395    -0.026129  virginica
# 149     0.960656    -0.024332     0.528249     0.163078  virginica
#
# [150 rows x 5 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.72962445, 0.22850762, 0.03668922, 0.00517871])

# %%
pca.components_
# Out:
# array([[ 0.52106591, -0.26934744,  0.5804131 ,  0.56485654],
#        [ 0.37741762,  0.92329566,  0.02449161,  0.06694199],
#        [-0.71956635,  0.24438178,  0.14212637,  0.63427274],
#        [-0.26128628,  0.12350962,  0.80144925, -0.52359713]])

# %%
class WrapperPCA:
    def __init__(self):
        pass
        
    def scaler(self, X):
        sc = StandardScaler()
        return sc.fit_transform(X)
    
    def label_encode(self, y):
        encode = LabelEncoder()
        return encode.fit_transform(y)
    
    def do_pca(self, X, Y, n_components):
        pca = PCA(n_components=n_components)
        pca.fit_transform(X)
        return pca
    
    def PCA_df(self, X, y, n_components):
        pca = self.do_pca(X, y, n_components)
        col_names = []
        for i in range(components):
            col_names.append(f"component {i+1}")
        principal_df = pd.DataFrame(data=principal_components,
                        columns=col_names)
        y = pd.DataFrame(y)
        principal_df = pd.concat([principal_df, y], axis=1)
        return principal_df
    
    def plot_PCA(self, X, y, n_components):
        df = self.PCA_def(X, y, n_components)
        figure, ax = plt.subplots(figsize=(5,5))
        ax.plot(pca.explained_variance_ratio_)
        ax.set_ylabel("explained variance ratio")
        ax.set_xticks(ticks=len((, labels=col_names)
        ax.set_title("PCA explained variance")
        plt.show()

# %%
iris

X = iris[iris.columns[0:-1]].values
y = iris[iris.columns[-1]].values

pca = WrapperPCA()

X = pca.scaler(X)
y = pca.label_encode(y)

df = pca.PCA_df(X, y, 3)

df
# Out:
#      component 1  component 2  component 3  component 4  0
# 0      -2.264703     0.480027    -0.127706    -0.024168  0
# 1      -2.080961    -0.674134    -0.234609    -0.103007  0
# 2      -2.364229    -0.341908     0.044201    -0.028377  0
# 3      -2.299384    -0.597395     0.091290     0.065956  0
# 4      -2.389842     0.646835     0.015738     0.035923  0
# ..           ...          ...          ...          ... ..
# 145     1.870503     0.386966     0.256274    -0.389257  2
# 146     1.564580    -0.896687    -0.026371    -0.220192  2
# 147     1.521170     0.269069     0.180178    -0.119171  2
# 148     1.372788     1.011254     0.933395    -0.026129  2
# 149     0.960656    -0.024332     0.528249     0.163078  2
#
# [150 rows x 5 columns]

# %%
pca.plot_PCA(X, y, 2)
